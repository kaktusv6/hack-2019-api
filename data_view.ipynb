# %%
# !pip3 install pytrends
# !pip3 install pymysql

# %%
import matplotlib

# %%
import pandas as pd
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='ru-RU', tz=360)

# %%
kw_list = ["кашель", "насморк", "высокая температура"]

# %%
pytrends.build_payload(kw_list, gprop='')

# %%
data_year = pytrends.get_historical_interest(kw_list, year_start=2014, month_start=5, 
                                 day_start=1, hour_start=0, year_end=2019,
                                 month_end=5, day_end=1, hour_end=0,
                                 geo='RU-MOW', cat=45)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7bd2718bf9a3> in <module>()
# ...

# %%
# date_day = data_year.rolling(window=24).mean().iloc[::24].dropna()

# %%
def insert(date, region_id, symptom_id, fact_interest):
    temp_insert = f"""
                        INSERT INTO `interest`(`region_id`, `symptom_id`, `fact_interest`, `date`)
                         VALUES ({region_id}, {symptom_id}, {fact_interest}, '{date}')
                """
    return(temp_insert)

# %%
connection = pymysql.connect(
    host='kaktusv6.beget.tech',
    user='kaktusv6_hack',
    password='Mamont500',
    db='kaktusv6_hack',
    charset='utf8mb4',
    cursorclass=DictCursor
)

# symptoms = pd.DataFrame(get_symptoms())
# regions = pd.DataFrame(get_regions())

# kw_list = list(symptoms.name.values)

# %%
for i in date_day.iterrows():
  print(i[1]['кашель'])
  break
# Out:
# 23.166666666666668

# %%
with connection.cursor() as cur:
  date_day = date_day.rolling(window=24).mean().iloc[::24].dropna()

      sympt_id = 2
      for row in date_day.iterrows():

          cur.execute(insert(date=row[0].date(), region_id=region_id, symptom_id=sympt_id, fact_interest=row[i+1][0]))
cur.commit()

# %%
kw_list = ['насморк', 'высокая температура']

# %%
with connection.cursor() as cur:
  for sympt in kw_list:
      sympt_id = symptoms[symptoms.name == sympt].id.values[0]
      for row in date_day.iterrows():

          cur.execute(insert(date=row[0].date(), region_id=1, symptom_id=sympt_id, fact_interest=row[1][sympt]))
connectin.commit()
# Out:
# /usr/local/lib/python3.6/dist-packages/pymysql/cursors.py:329: Warning: (1364, "Field 'id' doesn't have a default value")
#   self._do_get_result()

# %%
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-300-867cb5486458> in <module>()
# ----> 1 connection.commit()
#
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in commit(self)
#     418         """
#     419         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 420         self._read_ok_packet()
#     421
#     422     def rollback(self):
#
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in _read_ok_packet(self)
#     392
#     393     def _read_ok_packet(self):
# --> 394         pkt = self._read_packet()
#     395         if not pkt.is_ok_packet():
#     396             raise err.OperationalError(2014, "Command Out of Sync")
#
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     655         buff = b''
#     656         while True:
# ...

# %%
with connection.cursor() as cur:
    for region, region_id in regions.values:
        data = google_trends(kw=kw_list,  region=region)
        date_day = data.rolling(window=24).mean().iloc[::24].dropna()

        for i, sympt in enumerate(date_day.columns):
            sympt_id = symptoms[symptoms.name == sympt].id.values[0]
            for row in date_day.iterows():

                cur.execute(insert(date=row[0].date(), region_id=region_id, symptom_id=sympt_id, fact_interest=row[i+1][0]))

connection.commit()

# %%
import pymysql
from pymysql.cursors import DictCursor
import pandas as pd


connection = pymysql.connect(
    host='kaktusv6.beget.tech',
    user='kaktusv6_hack',
    password='Mamont500',
    db='kaktusv6_hack',
    charset='utf8mb4',
    cursorclass=DictCursor
)

def execute_query(query):
    with connection.cursor() as cursor:
        cursor.execute(query)
        return cursor.fetchall()


def get_symptoms():
    return execute_query("select * from symptoms")


def get_regions():
    return execute_query("select google_name, id from regions")


def get_diseases():
    return execute_query("select * from diseases")

def insert(date, region_id, symptom_id, fact_interest):
    temp_insert = f"""
                        INSERT INTO `interest`(`region_id`, `symptom_id`, `fact_interest`, `date`)
                         VALUES ({region_id}, {symptom_id}, {fact_interest}, {date})
                """
    return temp_insert

# %%
connection

# %%
kw_list = ["кашель", "насморк", "высокая температура"]
def google_trends(kw=None, year_start=2018, month_start=5, year_old=2019, month_old=5, region='RU'):
    data = pytrends.get_historical_interest(kw, year_start=year_start, month_start=month_start,
                                                 day_start=1, hour_start=0, year_end=year_old,
                                                 month_end=month_old, day_end=1, hour_end=0,
                                                 geo=region, cat=45)

    return data

# %%
google_trends(kw_list)
# Out:
#                      кашель  насморк  высокая температура  isPartial
# date
# 2018-05-01 00:00:00     100       21                    2      False
# 2018-05-01 01:00:00      82       13                    0      False
# 2018-05-01 02:00:00      73       12                    3      False
# 2018-05-01 03:00:00      74       17                    2      False
# 2018-05-01 04:00:00      65       14                    2      False
# 2018-05-01 05:00:00      50       16                    1      False
# 2018-05-01 06:00:00      43       10                    2      False
# 2018-05-01 07:00:00      34       10                    1      False
# 2018-05-01 08:00:00      29        7                    1      False
# 2018-05-01 09:00:00      25        9                    1      False
# 2018-05-01 10:00:00      27        7                    1      False
# 2018-05-01 11:00:00      32        5                    1      False
# ...

# %%
from matplotlib import pyplot

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_year.head()
# Out:
#                      кашель  Насморк  Высокая температура  грипп  isPartial
# date
# 2018-05-01 00:00:00     100       21                    2      7      False
# 2018-05-01 01:00:00      82       13                    0      7      False
# 2018-05-01 02:00:00      73       12                    3      3      False
# 2018-05-01 03:00:00      74       17                    2      4      False
# 2018-05-01 04:00:00      65       14                    2      3      False

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
kw_list = ["кашель", "насморк", "высокая температура", 'грипп']

data_year = pytrends.get_historical_interest(kw_list, year_start=2015, month_start=5, 
                                 day_start=1, hour_start=0, year_end=2019,
                                 month_end=5, day_end=1, hour_end=0,
                                 geo='RU-MOW', cat=45)


# pylab.rcParams['figure.figsize'] = (20, 5)
n_wind = 1440
pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(data_year.shape[0] - n_wind / 2)], moving_average(data_year['грипп'].values, n=n_wind))
# pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(data_year.shape[0] - n_wind / 2)], moving_average(data_year['кашель'].values, n=n_wind))
# pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(data_year.shape[0] - n_wind / 2)], moving_average(data_year['насморк'].values, n=n_wind))
# pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(data_year.shape[0] - n_wind / 2)], moving_average(data_year['высокая температура'].values, n=n_wind))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f970546a44a> in <module>()
#       1 kw_list = ["кашель", "насморк", "высокая температура", 'грипп']
#       2
# ----> 3 data_year = pytrends.get_historical_interest(kw_list, year_start=2015, month_start=5,
#       4                                  day_start=1, hour_start=0, year_end=2019,
#       5                                  month_end=5, day_end=1, hour_end=0,
#
# NameError: name 'pytrends' is not defined

# %%
pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(data_year.shape[0] - n_wind / 2)], moving_average(data_year['грипп'].values, n=n_wind))

# %%
pyplot.plot(data_year.index[int(n_wind / 2 - 1):int(len(data_year) - n_wind / 2)], moving_average(data_year['кашель'].values, n=n_wind))

# %%
new_date = data_year.rolling(window=24).mean().iloc[::24]
pyplot.plot(new_date.index.values, new_date.values)

# %%
date_day = data_year.rolling(window=24).mean().iloc[::24].dropna()

# %%
date_day['насморк'].iterows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-122c7ee38872> in <module>()
# ----> 1 date_day['насморк'].iterows()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'iterows'

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n
  
  
d = pd.rolling_mean(data_year['насморк'].values, window=24)
# pyplot.plot(data_year.index, moving_average(data_year['насморк'].values, n=24))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-214-93549e5b22b9> in <module>()
#       5
#       6
# ----> 7 d = pd.rolling_mean(data_year['насморк'].values, window=24)
#       8 # pyplot.plot(data_year.index, moving_average(data_year['насморк'].values, n=24))
#
# AttributeError: module 'pandas' has no attribute 'rolling_mean'

# %%
dt = data_year['насморк'].rolling(window=24)

# %%
dt
# Out:
# Rolling [window=24,center=False,axis=0]

# %%
# dt.sum().dropna()
dt.mean()
# Out:
# date
# 2017-05-01 00:00:00         NaN
# 2017-05-01 01:00:00         NaN
# 2017-05-01 02:00:00         NaN
# 2017-05-01 03:00:00         NaN
# 2017-05-01 04:00:00         NaN
# 2017-05-01 05:00:00         NaN
# 2017-05-01 06:00:00         NaN
# 2017-05-01 07:00:00         NaN
# 2017-05-01 08:00:00         NaN
# 2017-05-01 09:00:00         NaN
# 2017-05-01 10:00:00         NaN
# 2017-05-01 11:00:00         NaN
# 2017-05-01 12:00:00         NaN
# 2017-05-01 13:00:00         NaN
# 2017-05-01 14:00:00         NaN
# 2017-05-01 15:00:00         NaN
# 2017-05-01 16:00:00         NaN
# 2017-05-01 17:00:00         NaN
# 2017-05-01 18:00:00         NaN
# 2017-05-01 19:00:00         NaN
# 2017-05-01 20:00:00         NaN
# 2017-05-01 21:00:00         NaN
# 2017-05-01 22:00:00         NaN
# 2017-05-01 23:00:00    3.083333
# 2017-05-02 00:00:00    2.958333
# 2017-05-02 01:00:00    3.041667
# 2017-05-02 02:00:00    3.041667
# 2017-05-02 03:00:00    2.916667
# 2017-05-02 04:00:00    2.791667
# ...
